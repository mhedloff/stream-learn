# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
div_data = np.load("D:/diversity_data.npy")
div_data_df = pd.DataFrame(div_data, columns=['e', 'k', 'kw', 'dis', 'q'])

# %%
div_data_df
# Out:
#            e         k        kw       dis         q
# 0   0.288000  1.131000  0.209600  0.524000 -0.082227
# 1  -0.106667  1.054333  0.086933  0.217333  0.568456
# 2   0.040000  1.096667  0.154667  0.386667  0.218893
# 3   0.133333  1.107333  0.171733  0.429333  0.113518
# 4   0.069333  1.104000  0.166400  0.416000  0.063174
# ..       ...       ...       ...       ...       ...
# 94  0.112000  1.109333  0.174933  0.437333  0.189646
# 95 -0.184000  1.036667  0.058667  0.146667  0.728861
# 96  0.098667  1.108000  0.172800  0.432000 -0.000029
# 97 -0.090667  1.054000  0.086400  0.216000  0.325200
# 98  0.080000  1.103333  0.165333  0.413333  0.160286
#
# [99 rows x 5 columns]

# %%
x = np.linspace(start=1, stop=99, num=99)
plt.plot(x, div_data_df['kw'])
